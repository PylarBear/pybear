# %%
import base64
import pickle
from AutoGridSearch import autogridsearch_wrapper

# %%
# CONVERT GridSearchThresholdCV FUNCTION TO BASE64 ##################################################################

# %%
pickle_str = pickle.dumps(autogridsearch_wrapper)
b64_str = base64.b64encode(pickle_str).decode()

with open(r'/home/bear/Desktop/agsw_b64_dump', 'w') as f:
    f.write(b64_str)

# %%
# LAST UPDATED 24_02_29_18_13_00
AGSW_embed = 'gASVLQAAAAAAAACMDkF1dG9HcmlkU2VhcmNolIwWYXV0b2dyaWRzZWFyY2hfd3JhcHBlcpSTlC4='

# %%
# END CONVERT GridSearchThresholdCV FUNCTION TO BASE64 ##############################################################

# %%
# VALIDATE BASE64 ENCODING ###########################################################################################

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV as sklearn_GridSearchCV
from sklearn.linear_model import LogisticRegression as LR

# %%
_rows, _cols = 100, 10
X = np.random.randint(0,10,(_rows,_cols))
y = np.random.randint(0,2,_rows)

# %%
autogridsearch_wrapper = pickle.loads(base64.b64decode(AGSW_embed.encode()))

# %%
clf = LR(
            penalty='l2',
            dual=False,
            tol=0.0001,
            C=1.0,
            fit_intercept=True,
            intercept_scaling=1,
            class_weight=None,
            random_state=None,
            solver='lbfgs',
            max_iter=100,
            multi_class='auto',
            verbose=0,
            warm_start=False,
            n_jobs=None,
            l1_ratio=None,
)

# %%
sklearn_AutoGridSearchCV = autogridsearch_wrapper(sklearn_GridSearchCV)

# %%
searcher = sklearn_AutoGridSearchCV(
                                    estimator=clf,
                                    numerical_params={
                                                        'C': [np.logspace(-3,3,7), [7, 11, 6, 6, 6], 'soft_float']
                                    },
                                    string_params=None,
            
                                    total_passes=5,
                                    total_passes_is_hard=True,
                                    max_shifts=3,
                                    agscv_verbose=1,
            
                                    scoring='balanced_accuracy'
)

# %%
searcher.fit(X,y)
# Out:
# Pass 1 starting grids:
# C               [1.e-03 1.e-02 1.e-01 1.e+00 1.e+01 1.e+02 1.e+03]
# Running GridSearch... Done.
# Pass 1 best params: C: 100.0000
#
# Pass 2 starting grids:
# C               [ 83.3333 166.6667 250.     333.3333 416.6667 500.     583.3333 666.6667
#  750.     833.3333 916.6667]
# Running GridSearch... Done.
# Pass 2 best params: C: 83.3333
#
# Pass 3 starting grids:
# C               [ 23.8095  47.619   71.4286  95.2381 119.0476 142.8571]
# Running GridSearch... Done.
# Pass 3 best params: C: 95.2381
#
# Pass 4 starting grids:
# C               [ 78.2313  85.034   91.8367  98.6395 105.4422 112.2449]
# Running GridSearch... Done.
# Pass 4 best params: C: 85.0340
#
# Pass 5 starting grids:
# C               [80.1749 82.1186 84.0622 86.0058 87.9495 89.8931]
# Running GridSearch... Done.
# Pass 5 best params: C: 82.1186
#
# fit successfully completed 5 pass(es) with 0 shift pass(es).
# ...

# %%
searcher.score(X,y)
# Out:
# 0.6434343434343435

# %%
# END VALIDATE BASE64 ENCODING #######################################################################################
